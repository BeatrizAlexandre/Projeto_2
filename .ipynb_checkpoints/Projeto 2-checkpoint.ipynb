# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np

# %%
tw = pd.read_excel('tweets_lindt.xlsx')

# %%
tw.head()
# Out:
#                                          Treinamento Relevante  \
# 0                    lindt chocolate is so overrated         1
# 1  @elgliko hear that pitter patter in the back g...         0
# 2  rt @statutory_boy: the guy was addicted to dru...         0
# 3  @andreyasasylum @yourmomsuckstho hey, can you ...         1
# 4  great job by @noticgroup gms. come and see the...         1
#
#   Positivo/Negativo
# 0                 0
# 1               NaN
# 2               NaN
# 3                 1
# 4                 1

# %%
tw['Relevante'] == 1
# Out:
#                                            Treinamento  Relevante  \
# 0                      lindt chocolate is so overrated          1
# 1    @elgliko hear that pitter patter in the back g...          1
# 2    rt @statutory_boy: the guy was addicted to dru...          1
# 3    @andreyasasylum @yourmomsuckstho hey, can you ...          1
# 4    great job by @noticgroup gms. come and see the...          1
# 5    rt @blacktwittasa_: lmao guys i'm screaming 🤣🤣...          1
# 6    fuck i want candy or chocolate\n\ngoing ✈️ to ...          1
# 7                               @lindt_zwane thank you          1
# 8    @lindt_zwane misinterpret of of love sex money...          1
# 9    reebok emailed me to thank me for my collab po...          1
# 10   😥 news - coffee, irish cream &amp; hazelnut gi...          1
# 11   @earwolf @mattgourley @tvsandydaly a new augus...          1
# 12   @anewnamehere @verelaurent it's a chocolate mu...          1
# 13   how much out of 10 would you rate the 70% #dar...          1
# 14   rt @gemsatwork: is this real life? 😍we are ove...          1
# 15   rt @curiouspeterg: how are unicorns fake but g...          1
# 16   rt @crumbschester: 🍰 we are heading back to th...          1
# 17   so kira asked me to buy her chocolates - lindt...          1
# 18   rt @piwaaiko_xo: @lindt_zwane lmao nope😂😂\ntha...          1
# 19   #previous #post  the sensational taste of frui...          1
# 20   it's the little things in life that are the be...          1
# 21   co. i find them so sexy and intriguing. https:...          1
# 22   rt @serenbdavies: how do people have 1 square ...          1
# 23   rt @_bonga: guys. please put on your seatbelts...          1
# 24               @lindt_choc @ohloowatoscene very true          1
# 25   rt @_iamremy_: we all have that friend that gi...          1
# 26                         @lindt_m_ thank you baby ❤️          1
# 27   rt @kayepooot: so kira asked me to buy her cho...          1
# 28   rt @blackwave10: @mr_suitup love is...a tough ...          1
# 29   rt @spottersuper: this are the requirements ex...          1
# ..                                                 ...        ...
# 270  rt @wipkv: say cheese🧀\n#kookv https://t.co/7x...          1
# 271  @suga_ridge it's been bothering me, i really n...          1
# 272  @lindt_chocolate @lindt @lindtcanada yo lindt ...          1
# 273  @mr_suitup i'm just picturing my aunt with tho...          1
# 274  surprise me with lindt.\nbombard me with lindt...          1
# 275  rt @dixonjrdc: @skynewsaust @murraywatt @scott...          1
# 276  @typogee finally someone is on the same page i...          1
# 277  rt @leendorm: wow, guys! just wow! 🤣🤣😅😅🙈🙈 http...          1
# 278  rt @zinyile_rani: don’t understand how you peo...          1
# 279  @lindt_zwane sorry dear,don't mind those irres...          1
# 280  the lindt hoes gc after a piper monday 😩😩😩😂 @r...          1
# 281  rt @lindyyay: lmao oh. it gets worse?\ncool co...          1
# 282  the @lindt arrived safely! let's congratulate ...          1
# 283  @brownskinnono i swear there's a woman i know ...          1
# 284  rt @mo_izzy_: how many of us copied other peop...          1
# 285  rt @heidisibulawa: it's so cruel how careless ...          1
# 286  @hwhittenwrites lindt chocolate balls\na notep...          1
# 287  rt @awestwood_: me and gabrielle made the best...          1
# 288  @ainemohammad oh god, you 90% dark lindt eater...          1
# 289  we were talking about passion the other night....          1
# 290  orange lindt is beautiful https://t.co/svxaehonji          1
# 291  @thisisgaza duuuuudeeeeee come on!!!!! lindt w...          1
# 292  welcome home, lindt chocolate shop! https://t....          1
# 293  rt @lisasadgal: i can't wait til i have money ...          1
# 294  get a free greetings sticker when you buy a li...          1
# 295  rt @djspeedsta: “combos communicating” ft @okm...          1
# 296          @audio_slay don't go  .... i won't go too          1
# 297  rt @_bilzz: if you come across this tweet, i p...          1
# 298  rt @rachelpage13: i quit my job today &amp; my...          1
# 299  rt @caster800m: when the greatness meet up 😍❤....          1
#
#     Positivo/Negativo
# 0                   0
# 1                 NaN
# 2                 NaN
# 3                   1
# 4                   1
# 5                 NaN
# 6                   1
# 7                 NaN
# 8                 NaN
# 9                   1
# 10                  1
# 11                  1
# 12                  1
# 13                NaN
# 14                  1
# 15                NaN
# 16                NaN
# 17                  1
# 18                  0
# 19                  1
# 20                  1
# 21                NaN
# 22                  1
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                  1
# 28                NaN
# 29                NaN
# ..                ...
# 270               NaN
# 271               NaN
# 272                 0
# 273               NaN
# 274                 1
# 275                 0
# 276               NaN
# 277               NaN
# 278               NaN
# 279               NaN
# 280               0/1
# 281               NaN
# 282                 1
# 283               NaN
# 284               NaN
# 285               NaN
# 286                 1
# 287               NaN
# 288                 1
# 289               NaN
# 290                 1
# 291                 1
# 292                 1
# 293               NaN
# 294                 1
# 295               NaN
# 296               NaN
# 297               NaN
# 298               NaN
# 299               NaN
#
# [300 rows x 3 columns]
